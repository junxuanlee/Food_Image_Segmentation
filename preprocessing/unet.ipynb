# %%
import tensorflow as tf
tf.keras.backend.clear_session()
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)

# %%
#BACKBONES
#=============  ===== 
#Type           Names
#=============  =====
#VGG            ``'vgg16' 'vgg19'``
#ResNet         ``'resnet18' 'resnet34' 'resnet50' 'resnet101' 'resnet152'``
#SE-ResNet      ``'seresnet18' 'seresnet34' 'seresnet50' 'seresnet101' 'seresnet152'``
#ResNeXt        ``'resnext50' 'resnext101'``
#SE-ResNeXt     ``'seresnext50' 'seresnext101'``
#SENet154       ``'senet154'``
#DenseNet       ``'densenet121' 'densenet169' 'densenet201'`` 
#Inception      ``'inceptionv3' 'inceptionresnetv2'``
#MobileNet      ``'mobilenet' 'mobilenetv2'``
#EfficientNet   ``'efficientnetb0' 'efficientnetb1' 'efficientnetb2' 'efficientnetb3' 'efficientnetb4' 'efficientnetb5' efficientnetb6' efficientnetb7'``
#=============  =====

#All backbones have weights trained on 2012 ILSVRC ImageNet dataset (encoder_weights='imagenet')

# %%
#ACTIVATIONS
# relu, sigmoid, softmax, softplus, softsign, tanh, selu, elu, exponential

# %%
# go to C:\Users\Admin\anaconda3\Lib\site-packages\efficientnet\__init__.py
# line 71 -> keras.utils.get_custom_objects().update(custom_objects)
# restart kernel / restart IDE

from segmentation_models import Unet, FPN, Linknet, PSPNet
# Out:
# Segmentation Models: using `keras` framework.

# %%
backbone = 'resnet34'
shape=(416, 416, 3)
weights_pretrained = 'imagenet'
n_classes = 1
activ = 'sigmoid'
freeze = True #train only randomly initialized decoder in order not to damage weights of properly trained encoder

unet = Unet(backbone, input_shape=shape, encoder_weights=weights_pretrained,classes=n_classes, activation=activ, encoder_freeze=freeze) 
#fpn = FPN(backbone, input_shape=shape, encoder_weights=weights_pretrained,classes=n_classes, activation=activ, encoder_freeze=freeze) 
#linknet = Linknet(backbone, input_shape=shape, encoder_weights=weights_pretrained,classes=n_classes, activation=activ, encoder_freeze=freeze) 
#pspnet = PSPNet(backbone, input_shape=shape, encoder_weights=weights_pretrained,classes=n_classes, activation=activ, encoder_freeze=freeze) 

#set_trainable(model) #release all layers for training

# %%
import cv2
import numpy as np

pp = 'C:/Users/Admin/Desktop/jun/University/Year 4/GDP/work/code/notebooks/run/dataset/food1c/train/food_images/images/3.jpg'
img = cv2.imread(pp)
img = cv2.resize(img,(416,416))
img = np.expand_dims(img,0)

# %%
prediction = unet.predict(img)

# %%
unet.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# data (InputLayer)               [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 416, 416, 3)  9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 422, 422, 3)  0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 208, 208, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 208, 208, 64) 256         conv0[0][0]
# ...
